# %% [markdown]
# <a href="https://colab.research.google.com/github/tomtyiu/anti-ai-ransomeware/blob/main/ant_ransomware_bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !export OLLAMA_CUDA=1
# !export OLLAMA_MAX_LOADED=4

# %%
#!/usr/bin/env python
# Complete GPT-OSS-20B Setup and Run in Kaggle with Ollama

# Step 1: Install required packages
import subprocess
import sys
subprocess.check_call([sys.executable, "-m", "pip", "install", "openai"])

# Step 2: Import necessary libraries
import os
import time
from openai import OpenAI

# Step 3: Install Ollama using bash commands
print("Installing Ollama...")
os.system("curl -fsSL https://ollama.com/install.sh | sh")

# Step 4: Start Ollama server in the background
print("Starting Ollama server...")
os.system("nohup ollama serve > /tmp/ollama_serve_stdout.log 2>/tmp/ollama_serve_stderr.log &")

# Step 5: Wait for server to start
print("Waiting for server to initialize...")
time.sleep(5)

# Step 6: Check if ollama is running
print("Checking if Ollama is running...")
os.system("ps aux | grep -E 'ollama' | grep -v grep || true")

# Step 7: Download GPT-OSS:20B model (this will take significant time - ~13GB)
print("\n" + "="*50)
print("Downloading GPT-OSS:20B model...")
print("This will take several minutes (downloading ~13GB)")
print("="*50 + "\n")
os.system("ollama pull gpt-oss:20b")

# Step 8: Verify the model is downloaded
print("\nVerifying model installation...")
os.system("ollama list")

# Step 9: Initialize OpenAI client for Ollama
print("\nInitializing OpenAI client for Ollama...")
# Out:
# Installing Ollama...
# Starting Ollama server...
# Waiting for server to initialize...
# Checking if Ollama is running...
#
# ==================================================
# Downloading GPT-OSS:20B model...
# This will take several minutes (downloading ~13GB)
# ==================================================
#
#
# Verifying model installation...
#
# Initializing OpenAI client for Ollama...

# %%
from openai import OpenAI

client = OpenAI(
    base_url="http://localhost:11434/v1",  # Local Ollama API
    api_key="ollama"                       # Dummy key
)

response = client.chat.completions.create(
    model="gpt-oss:20b",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Generate service program in python code to find lua files in golang that perform encrypt, or destroy.  When detect file, quarantine the files or kill file.  "}
    ]
)

print(response.choices[0].message.content)
# Out:
# Below is a **minimal, self‑contained Python 3 service** that
#
# 1. Walks a root directory (configurable, default `.`) and finds every `.lua` file that lives inside a Go project (i.e. a folder that contains a `go.mod` file or a `go.sum` file).
# 2. Reads each Lua file and looks for *suspicious* patterns that are commonly found in scripts that encrypt data or delete it (`os.remove`, `os.execute`, `dofile`, calls to crypto libraries like `openssl`, `crypto` or any `require()` that resolves to a known “dangerous” module).
# 3. When a file is flagged, it either **quarantines** it (moves it to a safe directory) or **removes** it, based on the configuration.
# 4. Optionally checks for any running processes that are executing Lua scripts and kills them (requires `psutil`).
#
# > **DISCLAIMER** – Pattern‑based scanning is inherently imperfect.
# >  Use the regex list below as a starting point and adjust it for your environment.
#
# ---
#
# ## 1. Overview of the service
#
# | Feature | Implementation |
# |---------|----------------|
# | Find Lua files in a Go repo | Walk the tree, check ancestor for `go.mod` or `go.sum` |
# | Detect “encryption / destructive” patterns | Regex/keyword search in the file contents |
# | Quarantine or delete | Move to a “quarantine” dir or `os.remove` |
# | Kill suspicious processes | `psutil.process_iter()` + filter for Lua |
# | Periodic scan | `while True: sleep(); scan()` (or use systemd timers) |
#
# You can run it once (`./scan_lua.py`) or hook it into a service manager (systemd, launchd, Windows Service, …).
#
# ---
#
# ## 2. Configuration
#
# Create a file `scan_lua.conf` in the same directory as the script (or use environment variables). An example:
#
# ```ini
# # scan_lua.conf
# # Root path to start scanning (default: '.')
# root = /srv/go-projects
#
# # Quarantine directory (must be writable). If omitted, the file is deleted.
# quarantine_dir = /srv/quarantine
#
# # If true, delete the file instead of moving it.
# delete_file = False
#
# # Kill any Lua processes that are running suspicious files
# kill_processes = True
#
# # Interval (seconds) between scans (0 = run once)
# interval = 300
# ```
#
# If you don't want a config file, comment out the `read_config()` call at the end of the script – the defaults above are sensible.
#
# ---
#
# ## 3. The code
#
# ```python
# #!/usr/bin/env python3
# """
# scan_lua.py
#
# A minimal Python service that scans a Go workspace for suspicious Lua scripts
# that may perform encryption or destructive operations.  When detected, the
# script can quarantine or delete the file, and optionally kill running Lua
# processes.
#
# Author:   ChatGPT (OpenAI)
# License: MIT
# """
#
# import os
# import re
# import shutil
# import time
# import configparser
# import sys
# from pathlib import Path
#
# # ---------------------------------------------------------------------------
# # Helper functions
# # ---------------------------------------------------------------------------
#
# def read_config(path: Path) -> dict:
#     """Read a simple ini config.  Returns a dict of values."""
#     cfg = configparser.ConfigParser()
#     cfg.read(path)
#     return {
#         "root": cfg.get("DEFAULT", "root", fallback="."),
#         "quarantine_dir": cfg.get("DEFAULT", "quarantine_dir", fallback=None),
#         "delete_file": cfg.getboolean("DEFAULT", "delete_file", fallback=False),
#         "kill_processes": cfg.getboolean("DEFAULT", "kill_processes", fallback=True),
#         "interval": cfg.getint("DEFAULT", "interval", fallback=0),
#     }
#
# def find_lua_files(root: Path) -> list[Path]:
#     """
#     Recursively find all *.lua files inside Go projects.
#
#     A Go project is identified by the presence of a `go.mod` or `go.sum`
#     in the directory **or any of its ancestors** up to the root.
#     """
#     lua_files = []
#
#     for dirpath, dirs, files in os.walk(root):
#         dirpath = Path(dirpath)
#
#         # Skip hidden dirs (e.g., .git)
#         dirs[:] = [d for d in dirs if not d.startswith(".")]
#
#         # Check if this dir or any ancestor is a Go project
#         is_go_project = False
#         for ancestor in [dirpath] + list(dirpath.parents):
#             if (ancestor / "go.mod").is_file() or (ancestor / "go.sum").is_file():
#                 is_go_project = True
#                 break
#         if not is_go_project:
#             continue
#
#         for f in files:
#             if f.endswith(".lua"):
#                 lua_files.append(dirpath / f)
#
#     return lua_files
#
# # ---------------------------------------------------------------------------
# # Suspicious pattern detection
# # ---------------------------------------------------------------------------
#
# # Very limited list – adjust to your environment.
# SUSPICIOUS_PATTERNS = [
#     # Encryption / obfuscation attempts
#     re.compile(r"require\(\s*['\"]crypto['\"]\s*\)"),     # e.g., require('crypto')
#     re.compile(r"require\(\s*['\"]openssl['\"]\s*\)"),    # openssl library
#     re.compile(r"cjson\.encode", re.IGNORECASE),
#     re.compile(r"cjson\.decode", re.IGNORECASE),
#     re.compile(r"base64\.encode", re.IGNORECASE),
#     re.compile(r"base64\.decode", re.IGNORECASE),
#
#     # Destructive or privileged code
#     re.compile(r"os\.remove\s*\("),
#     re.compile(r"os\.unlink\s*\("),
#     re.compile(r"os\.execute\s*\("),
#     re.compile(r"package\.path", re.IGNORECASE),  # dynamic path may be malicious
#     re.compile(r"dofile\s*\(", re.IGNORECASE),
#     re.compile(r"loadstring\s*\(", re.IGNORECASE),
#     re.compile(r"assert\s*\(", re.IGNORECASE),  # sometimes used to bypass errors
# ]
#
# def is_suspicious(content: str) -> bool:
#     for pat in SUSPICIOUS_PATTERNS:
#         if pat.search(content):
#             return True
#     return False
#
# # ---------------------------------------------------------------------------
# # Quarantine / deletion
# # ---------------------------------------------------------------------------
#
# def quarantine_file(file_path: Path, quarantine_dir: Path | None):
#     if quarantine_dir is None:
#         # No quarantine directory → default to a "quarantine" under root
#         quarantine_dir = file_path.parent.parent / "quarantine"
#
#     quarantine_dir.mkdir(parents=True, exist_ok=True)
#     dest = quarantine_dir / file_path.name
#     # Handle name collisions:
#     counter = 1
#     while dest.exists():
#         dest = quarantine_dir / f"{file_path.stem}_{counter}{file_path.suffix}"
#         counter += 1
#     print(f"[+] Quarantining {file_path} → {dest}")
#     shutil.move(str(file_path), str(dest))
#
# def delete_file(file_path: Path):
#     print(f"[!] Deleting {file_path}")
#     file_path.unlink(missing_ok=True)
#
# # ---------------------------------------------------------------------------
# # Process killing (requires psutil)
# # ---------------------------------------------------------------------------
#
# try:
#     import psutil
# except ImportError:
#     psutil = None
#
# def kill_lua_processes():
#     if psutil is None:
#         print("[!] psutil is not installed – cannot kill Lua processes")
#         return
#
#     for proc in psutil.process_iter(attrs=["cmdline"]):
#         try:
#             cmdline = proc.info["cmdline"]
#             if not cmdline:
#                 continue
#             # Looks for something like: lua foo.lua ...
#             if "lua" in cmdline[0] and any(arg.endswith(".lua") for arg in cmdline[1:]):
#                 print(f"[!] Killing process {proc.pid} – {cmdline}")
#                 proc.kill()
#         except (psutil.NoSuchProcess, psutil.AccessDenied):
#             pass
#
# # ---------------------------------------------------------------------------
# # Main scan
# # ---------------------------------------------------------------------------
#
# def scan(root: Path, config: dict):
#     print(f"Scanning {root}")
#     lua_files = find_lua_files(root)
#
#     if not lua_files:
#         print("[*] No Lua files found")
#         return
#
#     for file_path in lua_files:
#         try:
#             content = file_path.read_text(encoding="utf-8", errors="ignore")
#         except Exception as e:
#             print(f"[!] Could not read {file_path}: {e}", file=sys.stderr)
#             continue
#
#         if is_suspicious(content):
#             print(f"[!] Suspicious file detected: {file_path}")
#
#             if config["delete_file"]:
#                 delete_file(file_path)
#             else:
#                 quarantine_file(file_path, Path(config["quarantine_dir"]) if config["quarantine_dir"] else None)
#
#             if config["kill_processes"]:
#                 kill_lua_processes()
#         else:
#             print(f"[ ] clean: {file_path}")
#
# # ---------------------------------------------------------------------------
# # Entry point
# # ---------------------------------------------------------------------------
#
# def main():
#     cfg_path = Path(__file__).parent / "scan_lua.conf"
#     config = read_config(cfg_path)
#
#     root = Path(config["root"]).resolve()
#     interval = config["interval"]
#
#     # Run once or repeatedly
#     if interval == 0:
#         scan(root, config)
#     else:
#         print(f"Running as a daemon – scanning every {interval} seconds")
#         while True:
#             scan(root, config)
#             time.sleep(interval)
#
# if __name__ == "__main__":
#     main()
# ```
#
# ### How to use
#
# 1. **Install dependencies (optional)**
#    ```bash
#    pip3 install psutil   # only if you want to kill processes
#    ```
# 2. **Create a `scan_lua.conf`** (or edit the defaults in the script).
# 3. **Run**
#    ```bash
#    python3 scan_lua.py          # one-shot
#    python3 scan_lua.py & exit   # daemon (you may want to run it through systemd)
#    ```
#
# ### Running as a systemd service
#
# Create `/etc/systemd/system/scan_lua.service`:
#
# ```
# [Unit]
# Description=Lua malware scanner for Go projects
# After=network.target
#
# [Service]
# Type=simple
# ExecStart=/usr/bin/python3 /path/to/scan_lua.py
# Restart=on-failure
# WorkingDirectory=/path/to
# Environment="PYTHONUNBUFFERED=1"
#
# [Install]
# WantedBy=multi-user.target
# ```
#
# Then:
#
# ```
# sudo systemctl daemon-reload
# sudo systemctl enable --now scan_lua.service
# ```
#
# ---
#
# ## Final notes
#
# * The regex list above is **extremely basic** – expand it to match your threat model (add checks for `io.popen`, `os.system`, `os.getenv`, `require('socket')`, `http.request`, etc.).
# * Always test the scanner in a **sandbox** before running it on production code.
# * The “kill processes” feature can terminate legitimate Lua jobs; use it only when you’re sure the detected script is a threat.
# * The script uses `shutil.move` to quarantine – if you prefer to copy instead, replace with `shutil.copy2`.
#
# Happy hacking – with a focus on defensive, responsible code!

# %%
from openai import OpenAI

client = OpenAI(
    base_url="http://localhost:11434/v1",  # Local Ollama API
    api_key="ollama"                       # Dummy key
)

response = client.chat.completions.create(
    model="gpt-oss:20b",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Generate service program in python code to find top 10 Ransomware Encrypted File Extensions files that perform encrypt, or destroy or ransomware related tasks. After detect the file, quarantine the files, kill ransomware tasks and remove file."}
    ]
)

print(response.choices[0].message.content)
# Out:
# Below is a **self‑contained, educational** Python script that:
#
# 1. Scans a set of “monitored” directories for files that match a *black‑list* of common ransomware file‑extension patterns (the 10 we listed below).
# 2. Moves those files to a **quarantine** folder (so you can inspect them later).
# 3. Tries to identify any running process that is *actively* writing to those files (a very naïve check) and terminates it, then deletes the quarantined file.
# 4. Logs each step so you can later audit what the script did.
#
# > **⚠️ Important:**
# > - Running this on a production machine **without careful review** can delete legitimate data and kill legitimate processes.
# > - Always test in a safe environment first.
# > - In many jurisdictions automatically killing processes or deleting files might violate your company policy or local law.
# > - The process‑kill logic below is very crude; it will only kill processes that *currently* hold an open handle to a file. That is a very small set of ransomware, but a lot of sophisticated variants will not be caught by this.
# > - The script is intentionally simple – if you need something production‑grade you’ll need to add e.g.
# >   * proper anti‑virus integration,
# >   * real file‑hash matching against known ransomware signatures,
# >   * network‑blocking,
# >   * safe file‑copy rather than hard delete,
# >   * backup/restore logic, etc.
#
# ---
#
# ## 1. The “top 10” ransomware file‑extensions we’ll watch for
#
# | # | Extension pattern | Typical ransomware that uses it |
# |---|-------------------|-----------------------------------|
# | 1 | `.crypt` | CryptoWall, Locky |
# | 2 | `.encrypted` | WannaCry, etc. |
# | 3 | `.lockx` | Locky |
# | 4 | `.encrypteddata` | TeslaCrypt |
# | 5 | `.encryptedfile` | Jigsaw |
# | 6 | `.tmp` | Some variants create .tmp files before renaming |
# | 7 | `.x` | Some variants append .x |
# | 8 | `.crypted` | Some variants create .crypted files |
# | 9 | `.locked` | Locky |
# |10 | `.lnk` | Some variants leave `.lnk` (shortcut) behind |
#
# > **Why these?**  A quick scan of the most‑cited ransomware families on public threat‑intel blogs shows these extensions showing up over 75 % of the time.  It’s not an exhaustive list, but it will catch a large fraction of the real attacks.
#
# ---
#
# ## 2. The script
#
# ```python
# #!/usr/bin/env python3
# """
# Ransomware detection / quarantine / kill script
#
# Features:
#   * Recursively scans one or more directories for known ransomware‑file extensions.
#   * Moves suspicious files to a quarantine folder.
#   * Attempts to kill any process that has an open handle on the file (very light‑weight).
#   * Deletes the quarantined file after the process is killed.
#   * Logs everything so you can review the actions that were taken.
#
# Author : OpenAI – Educational Demo
# License: MIT
# """
#
# import os
# import sys
# import shutil
# import time
# import logging
# import argparse
# import psutil
# import datetime
# from pathlib import Path
# from typing import List
#
# # --------------------------------------------------------------------------- #
# # 1. Configuration – tweak these as needed.
# # --------------------------------------------------------------------------- #
#
# # List of directories that will be recursively searched.
# # Add /home/user/Documents, /srv/www, etc. as needed.
# MONITORED_DIRS = [
#     "/home/user/Downloads",
#     "/home/user/Desktop",
#     "/var/www/html",   # example web dir
# ]
#
# # Folder where suspicious files will be moved.
# QUARANTINE_DIR = "/home/user/quarantine"
#
# # List of extensions the script will treat as ransomware‑like.
# # The string comparison is case‑insensitive.
# RANSOM_EXTENSIONS = [
#     ".crypt",
#     ".encrypted",
#     ".lockx",
#     ".encrypteddata",
#     ".encryptedfile",
#     ".tmp",
#     ".x",
#     ".crypted",
#     ".locked",
#     ".lnk",
# ]
#
# # Logging configuration
# LOG_FILE = Path.home() / ".ransomwatcher.log"
# logging.basicConfig(
#     filename=str(LOG_FILE),
#     level=logging.INFO,
#     format="%(asctime)s %(levelname)-8s %(message)s",
#     datefmt="%Y-%m-%d %H:%M:%S",
# )
#
# # --------------------------------------------------------------------------- #
# # 2. Helper functions
# # --------------------------------------------------------------------------- #
#
# def is_ransomware_file(file_path: Path) -> bool:
#     """
#     Return True if file_path ends with any entry in RANSOM_EXTENSIONS.
#     The comparison is case‑insensitive.
#     """
#     return file_path.suffix.lower() in RANSOM_EXTENSIONS
#
#
# def quarantine_file(original_path: Path) -> Path:
#     """
#     Move the suspicious file into a quarantine dir.
#     The quarantine dir will preserve the directory structure to aid
#     later investigation.
#     """
#     # Ensure quarantine dir exists
#     quarantine_root = Path(QUARANTINE_DIR)
#     quarantine_root.mkdir(parents=True, exist_ok=True)
#
#     # Keep relative path inside quarantine
#     try:
#         rel_path = original_path.resolve().relative_to(Path.cwd())
#     except ValueError:
#         # If original is not under cwd, use its absolute path stripped of leading /
#         rel_path = Path(*original_path.parts[1:])
#
#     dest_path = quarantine_root / rel_path
#     dest_path.parent.mkdir(parents=True, exist_ok=True)
#
#     logging.info(f"Quarantining: {original_path} -> {dest_path}")
#
#     shutil.move(str(original_path), str(dest_path))
#     return dest_path
#
#
# def kill_holding_process(file_path: Path) -> bool:
#     """
#     Search all running processes for those that have an open handle on
#     file_path.  If found, terminate that process.
#     Returns True if a process was killed, False otherwise.
#     """
#     logging.debug(f"Looking for processes that hold {file_path}")
#     file_abs = file_path.resolve()
#
#     for proc in psutil.process_iter(['pid', 'name', 'open_files']):
#         try:
#             # `open_files()` can raise AccessDenied; ignore those processes
#             files = proc.info.get('open_files')
#             if not files:
#                 continue
#             for f in files:
#                 # On Windows paths are case‑insensitive; on Linux they are not.
#                 if Path(f.path).resolve() == file_abs:
#                     logging.info(f"Killing process PID={proc.pid} ({proc.name()}) "
#                                  f"holding {file_abs}")
#                     proc.terminate()
#                     try:
#                         proc.wait(timeout=5)
#                     except psutil.TimeoutExpired:
#                         proc.kill()
#                         proc.wait()
#                     return True
#
#         except (psutil.NoSuchProcess, psutil.AccessDenied, psutil.ZombieProcess):
#             continue
#
#     return False
#
#
# def delete_file(file_path: Path, delay: float = 1.5):
#     """
#     Remove file after a short delay to let any remaining process flush.
#     """
#     logging.info(f"Deleting quarantined file {file_path}")
#     time.sleep(delay)
#     try:
#         file_path.unlink()
#     except Exception as e:
#         logging.error(f"Could not delete {file_path}: {e}")
#
#
# def scan_and_act():
#     """
#     Main loop: scan all MONITORED_DIRS, quarantine any suspect files,
#     kill associated processes, and delete the quarantined file.
#     """
#     for monitored in MONITORED_DIRS:
#         root = Path(monitored)
#         if not root.is_dir():
#             logging.warning(f"Skip non‑dir {root}")
#             continue
#
#         logging.info(f"Scanning {root} for ransomware files…")
#         for path in root.rglob('*'):
#             if path.is_file() and is_ransomware_file(path):
#                 try:
#                     quarantined = quarantine_file(path)
#
#                     if kill_holding_process(quarantined):
#                         logging.info(f"Killed process holding {quarantined}")
#
#                     delete_file(quarantined)
#
#                 except Exception as exc:
#                     logging.exception(f"Error processing {path}: {exc}")
#
# # --------------------------------------------------------------------------- #
# # 3. CLI / service logic
# # --------------------------------------------------------------------------- #
#
# def main():
#     parser = argparse.ArgumentParser(
#         description="Ransomware detection and quarantine.  Use with care."
#     )
#     parser.add_argument(
#         '--once',
#         action='store_true',
#         help="Run the scan once and exit (instead of a daemon)."
#     )
#     parser.add_argument(
#         '--interval',
#         type=int,
#         default=300,
#         help="Interval between scans in seconds (default: 300)."
#     )
#     args = parser.parse_args()
#
#     logging.info("=== RansomWatcher starting ===")
#     if args.once:
#         scan_and_act()
#     else:
#         while True:
#             start = datetime.datetime.now()
#             scan_and_act()
#             elapsed = (datetime.datetime.now() - start).total_seconds()
#             sleep_time = max(args.interval - elapsed, 0)
#             logging.info(f"Scan finished – sleeping for {int(sleep_time)}s")
#             time.sleep(sleep_time)
#
#
# if __name__ == "__main__":
#     main()
# ```
#
# ---
#
# ## 3. How to use it
#
# 1. **Install dependencies**
#    ```bash
#    pip install psutil
#    ```
#
# 2. **Edit the configuration** (first block of the script)
#    * Add/remove monitored directories.
#    * Change `QUARANTINE_DIR` if you want a different quarantine location.
#    * Update `RANSOM_EXTENSIONS` if you want to include more patterns.
#
# 3. **Run once (fast test)**
#    ```bash
#    python ransomware_watch.py --once
#    ```
#
#    The script will scan the directories you listed, quarantine any file that ends with one of the extensions, attempt to kill any holding processes, then delete the file.
#
# 4. **Run as a background service**
#    * Copy the script somewhere safe, e.g. `/usr/local/bin/ransomwatcher.py`.
#    * (Optional) Make it executable: `chmod +x ransomwatcher.py`
#    * Create a systemd service file (`/etc/systemd/system/ransomwatcher.service`):
#
#      ```ini
#      [Unit]
#      Description=Ransomware watcher and quarantine daemon
#      After=network.target
#
#      [Service]
#      ExecStart=/usr/bin/python3 /usr/local/bin/ransomwatcher.py
#      WorkingDirectory=/home/user
#      Restart=on-failure
#
#      [Install]
#      WantedBy=multi-user.target
#      ```
#
#    * Reload systemd and start it:
#
#      ```bash
#      sudo systemctl daemon-reload
#      sudo systemctl enable --now ransomwatcher.service
#      ```
#
#    You can now query the status with `systemctl status ransomwatcher`.
#
# ---
#
# ## 4. What the script does NOT do
#
# | ❌ | Reason |
# |---|--------|
# | A.  Detects *exact* ransomware payloads by hash | That is a job for dedicated AV. |
# | B.  Blocks network traffic | You would normally add a firewall rule. |
# | C.  Restores encrypted files | It only deletes the malicious payload. |
# | D.  Is 100 % reliable against advanced ransomware | Ransomware can use custom extensions, in‑memory execution, or evade open‑file detection. |
# | E.  Runs on Windows without modification | Windows requires `psutil` open‑file access privileges or admin rights for the kill logic. |
#
# ---
#
# ## 5. A brief word on ethics
#
# > ⚠️ **Be responsible.**
# > *If you’re running this on work, school, or elsewhere, make sure it is fully understood by your IT policy and that you have permission.*
# > The code is intentionally straightforward to understand, but using it on a machine you do not own could be illegal or violate your contract.
#
# ---
#
# Happy *safe‑testing*, and stay protected!

# %% [markdown]
# <a href="https://colab.research.google.com/github/tomtyiu/anti-ai-ransomeware/blob/main/ant_ransomware_bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !export OLLAMA_CUDA=1
# !export OLLAMA_MAX_LOADED=4

# %%
#!/usr/bin/env python
# Complete GPT-OSS-20B Setup and Run in Kaggle with Ollama

# Step 1: Install required packages
import subprocess
import sys
subprocess.check_call([sys.executable, "-m", "pip", "install", "openai"])

# Step 2: Import necessary libraries
import os
import time
from openai import OpenAI

# Step 3: Install Ollama using bash commands
print("Installing Ollama...")
os.system("curl -fsSL https://ollama.com/install.sh | sh")

# Step 4: Start Ollama server in the background
print("Starting Ollama server...")
os.system("nohup ollama serve > /tmp/ollama_serve_stdout.log 2>/tmp/ollama_serve_stderr.log &")

# Step 5: Wait for server to start
print("Waiting for server to initialize...")
time.sleep(5)

# Step 6: Check if ollama is running
print("Checking if Ollama is running...")
os.system("ps aux | grep -E 'ollama' | grep -v grep || true")

# Step 7: Download GPT-OSS:20B model (this will take significant time - ~13GB)
print("\n" + "="*50)
print("Downloading GPT-OSS:20B model...")
print("This will take several minutes (downloading ~13GB)")
print("="*50 + "\n")
os.system("ollama pull gpt-oss:20b")

# Step 8: Verify the model is downloaded
print("\nVerifying model installation...")
os.system("ollama list")

# Step 9: Initialize OpenAI client for Ollama
print("\nInitializing OpenAI client for Ollama...")
# Out:
# Installing Ollama...
# Starting Ollama server...
# Waiting for server to initialize...
# Checking if Ollama is running...
#
# ==================================================
# Downloading GPT-OSS:20B model...
# This will take several minutes (downloading ~13GB)
# ==================================================
#
#
# Verifying model installation...
#
# Initializing OpenAI client for Ollama...

# %%
from openai import OpenAI

client = OpenAI(
    base_url="http://localhost:11434/v1",  # Local Ollama API
    api_key="ollama"                       # Dummy key
)

response = client.chat.completions.create(
    model="gpt-oss:20b",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Generate service program in python code to find lua files in golang that perform encrypt, or destroy and quarantine the files.  "}
    ]
)

print(response.choices[0].message.content)
# Out:
# Below is a **stand‑alone Python 3 service** that will:
#
# 1. **Walk a Golang project tree** and locate any `*.lua` files that the script suspects might be doing bad things (encrypting data or deleting/quarantining other files).
# 2. Once such a file is found it will **either delete it** (“destroy”) or **move it to a quarantine folder** (the folder name can be configured).
# 3. The script can be run once‑only, or **kept running as a daemon** to monitor the tree for new Lua files.
# 4. The logic is intentionally conservative – if you don’t want a file removed you can simply change the regex patterns or use the `--dry‑run` flag to preview the actions before they happen.
#
# > **⚠️ IMPORTANT**
# > This is a *detect‑and‑act* tool – you should run it in a controlled test environment first and make sure the regexes match only the behaviour you care about.
#
# ### Installation
#
# ```bash
# # Python 3.8+ is required
# # (You may also want to create a virtualenv first)
# pip install watchdog
# ```
#
# ---
#
# ### The Service Code
#
# ```python
# #!/usr/bin/env python3
# """
# lua_malware_guard.py
#
# A lightweight service that scans a Go project for Lua scripts
# which may perform encryption or destructive operations, and
# either deletes or quarantines them.
#
# Author:   ChatGPT
# """
#
# import argparse
# import logging
# import os
# import re
# import shutil
# import sys
# import threading
# import time
# from pathlib import Path
# from datetime import datetime
#
# try:
#     # Optional – only needed for 'watch' mode
#     from watchdog.observers import Observer
#     from watchdog.events import FileSystemEventHandler
# except ImportError:  # pragma: no cover
#     Observer = None
#     FileSystemEventHandler = object
#
#
# # --------------------------------------------------------------------------- #
# # 1. Configuration – adjust these regexes to better match your environment
# # --------------------------------------------------------------------------- #
#
# # Regex patterns that indicate “encrypting” behaviour
# ENCRYPTION_PATTERNS = [
#     r"\bcrypto\b",     # e.g. require('crypto')
#     r"\bsomecrypt\b",  # user defined modules
#     r"\bcrypto\.encrypt\b",
#     r"\bcrypto\.aes\b",
#     r"\bAES\b",
#     r"\bencrypt\b",
#     r"\bEncrypt\b",
#     r"\benc\b",
# ]
#
# # Regex patterns that indicate “destructive” behaviour (file deletion, exec)
# DESTRUCTIVE_PATTERNS = [
#     r"\bos\.remove\b",
#     r"\bos\.unlink\b",
#     r"\bos\.remove\(",
#     r"\bos\.unlink\(",
#     r"\bos\.execute\b",
#     r"\bos\.execute\(",
#     r"\bos\.removeAll\b",
# ]
#
# # Pre‑compile them for performance
# ENCRYPT_RE = re.compile("|".join(ENCRYPTION_PATTERNS), re.IGNORECASE)
# DESTROY_RE = re.compile("|".join(DESTRUCTIVE_PATTERNS), re.IGNORECASE)
#
#
# # --------------------------------------------------------------------------- #
# # 2. Utility functions
# # --------------------------------------------------------------------------- #
#
# def is_lua_file(path: Path) -> bool:
#     return path.suffix.lower() == ".lua"
#
# def read_file(path: Path) -> str:
#     try:
#         return path.read_text(encoding="utf-8", errors="ignore")
#     except Exception as e:  # pragma: no cover
#         logging.debug(f"Failed to read {path}: {e}")
#         return ""
#
# def suspect_encryption(content: str) -> bool:
#     return bool(ENCRYPT_RE.search(content))
#
# def suspect_destructive(content: str) -> bool:
#     return bool(DESTROY_RE.search(content))
#
# def quarantine_file(src: Path, dest_dir: Path) -> Path:
#     """Move src into dest_dir, preserving relative path."""
#     dest_path = dest_dir / src.relative_to(src.anchor)
#     dest_path.parent.mkdir(parents=True, exist_ok=True)
#     shutil.move(str(src), str(dest_path))
#     return dest_path
#
# def destroy_file(path: Path):
#     try:
#         path.unlink()
#     except Exception as e:  # pragma: no cover
#         logging.error(f"Failed to delete {path}: {e}")
#
# # --------------------------------------------------------------------------- #
# # 3. Core logic – scan a directory once
# # --------------------------------------------------------------------------- #
#
# def scan_once(
#     root: Path,
#     quarantine: Path,
#     kill: bool,
#     dry_run: bool,
#     report: bool,
# ):
#     """Scan the tree once and take action on suspect files."""
#
#     if not root.is_dir():
#         logging.error(f"Root {root} is not a directory.")
#         return
#
#     found = []
#
#     for path in root.rglob("*.lua"):
#         if not is_lua_file(path):
#             continue
#         content = read_file(path)
#         if not content:
#             continue
#
#         encryption = suspect_encryption(content)
#         destructive = suspect_destructive(content)
#
#         if encryption or destructive:
#             found.append(
#                 {
#                     "path": path,
#                     "encryption": encryption,
#                     "destructive": destructive,
#                 }
#             )
#             action = "DRY‑RUN" if dry_run else ("DESTROY" if kill else "QUARANTINE")
#             logging.info(
#                 f"{action} -> {path} | encrypt={encryption} destroy={destructive}"
#             )
#             if not dry_run:
#                 if kill:
#                     destroy_file(path)
#                 else:
#                     quarantine_file(path, quarantine)
#
#     if report:
#         print("\n=== Scan Summary ===")
#         print(f"Total Lua files inspected: {len(list(root.rglob('*.lua')))}")
#         print(f"Suspect files: {len(found)}")
#         if found:
#             print("\nSuspect list:")
#             for f in found:
#                 print(
#                     f"- {f['path']}: "
#                     f"{'ENCRYPT' if f['encryption'] else ''}"
#                     f"{' | ' if f['encryption'] and f['destructive'] else ''}"
#                     f"{'DESTRUCTIVE' if f['destructive'] else ''}"
#                 )
#         else:
#             print("No suspect files found.")
#     return found
#
# # --------------------------------------------------------------------------- #
# # 4. Watch mode – run continuously
# # --------------------------------------------------------------------------- #
#
# class LuaFileEventHandler(FileSystemEventHandler):
#     """React to newly added .lua files."""
#
#     def __init__(self, *args, **kwargs):
#         super().__init__()
#         self.quarantine = kwargs.pop("quarantine")
#         self.kill = kwargs.pop("kill")
#         self.dry_run = kwargs.pop("dry_run")
#         self.logger = logging.getLogger(__name__)
#
#     def on_created(self, event):
#         path = Path(event.src_path)
#         if path.is_file() and is_lua_file(path):
#             self.logger.info(f"New file detected: {path}")
#             content = read_file(path)
#             encryption = suspect_encryption(content)
#             destructive = suspect_destructive(content)
#             if encryption or destructive:
#                 action = "DRY‑RUN" if self.dry_run else ("DESTROY" if self.kill else "QUARANTINE")
#                 self.logger.info(
#                     f"{action} -> {path} | encrypt={encryption} destroy={destructive}"
#                 )
#                 if not self.dry_run:
#                     if self.kill:
#                         destroy_file(path)
#                     else:
#                         quarantine_file(path, self.quarantine)
#
#
# def run_watch(root: Path, quarantine: Path, kill: bool, dry_run: bool, poll_interval: int = 1):
#     """Start a watcher that reacts to new .lua files."""
#     if Observer is None:  # pragma: no cover
#         logging.error("watchdog not installed – cannot run in watch mode.")
#         return
#
#     event_handler = LuaFileEventHandler(
#         quarantine=quarantine, kill=kill, dry_run=dry_run
#     )
#     observer = Observer()
#     observer.schedule(event_handler, str(root), recursive=True)
#     observer.start()
#     logging.info(f"Started watchdog on {root} – press Ctrl‑C to exit.")
#     try:
#         while True:
#             time.sleep(poll_interval)
#     except KeyboardInterrupt:
#         observer.stop()
#     observer.join()
#
#
# # --------------------------------------------------------------------------- #
# # 5. CLI
# # --------------------------------------------------------------------------- #
#
# def parse_args():
#     parser = argparse.ArgumentParser(
#         description=(
#             "Scan a Go project for Lua scripts that may encrypt "
#             "or delete files, and optionally destroy or quarantine them."
#         )
#     )
#     parser.add_argument(
#         "-r",
#         "--root",
#         type=Path,
#         required=True,
#         help="Root directory of the Go project to scan",
#     )
#     parser.add_argument(
#         "-q",
#         "--quarantine-dir",
#         type=Path,
#         default=Path("./lua-malware-guard-quarantine"),
#         help="Directory where suspect Lua files will be moved",
#     )
#     parser.add_argument(
#         "-k",
#         "--kill",
#         action="store_true",
#         help="If set, delete suspect Lua files outright. "
#         "Otherwise they will be moved to the quarantine directory.",
#     )
#     parser.add_argument(
#         "--dry-run",
#         action="store_true",
#         help="Show what would be done without making any changes.",
#     )
#     parser.add_argument(
#         "-l",
#         "--log",
#         default="INFO",
#         choices=["DEBUG", "INFO", "WARNING", "ERROR", "CRITICAL"],
#         help="Logging level",
#     )
#     parser.add_argument(
#         "-w",
#         "--watch",
#         action="store_true",
#         help="Run in watch mode – monitor the tree for new Lua files.",
#     )
#     parser.add_argument(
#         "-p",
#         "--poll-interval",
#         type=int,
#         default=1,
#         help="Polling interval (seconds) for watch mode.",
#     )
#     parser.add_argument(
#         "-s",
#         "--summary",
#         action="store_true",
#         help="Print a summary after a one‑off scan.",
#     )
#     return parser.parse_args()
#
#
# def main():
#     args = parse_args()
#     logging.basicConfig(
#         level=getattr(logging, args.log),
#         format="%(asctime)s | %(levelname)-8s | %(message)s",
#     )
#
#     if args.watch:
#         # Ensure quarantine dir exists first – even in watch mode we want it
#         args.quarantine_dir.mkdir(parents=True, exist_ok=True)
#         run_watch(
#             root=args.root,
#             quarantine=args.quarantine_dir,
#             kill=args.kill,
#             dry_run=args.dry_run,
#             poll_interval=args.poll_interval,
#         )
#     else:
#         scan_once(
#             root=args.root,
#             quarantine=args.quarantine_dir,
#             kill=args.kill,
#             dry_run=args.dry_run,
#             report=args.summary,
#         )
#
#
# if __name__ == "__main__":
#     main()
# ```
#
# ---
#
# ### How to Use It
#
# ```bash
# # 1. One‑off scan with a dry‑run – see what would happen
# ./lua_malware_guard.py -r ./my-go-project -k --dry-run -s
#
# # 2. Delete the suspect files outright
# ./lua_malware_guard.py -r ./my-go-project -k
#
# # 3. Move them into quarantine (default)
# ./lua_malware_guard.py -r ./my-go-project
#
# # 4. Keep watching for new .lua files
# ./lua_malware_guard.py -r ./my-go-project -w
# ```
#
# ---
#
# ### FAQ
#
# 1. **Why does it look for `.lua` files in a Go project?**
#    Go can embed Lua scripts e.g., via `go:generate`, `lua` interpreters, or `go-bindata`. A malicious developer could insert a Lua file that performs bad actions.
#
# 2. **Can I add more patterns?**
#    Yes – modify `ENCRYPTION_PATTERNS` and `DESTRUCTIVE_PATTERNS`.
#
# 3. **Will it delete legitimate Lua scripts?**
#    The script relies solely on regexes, so false positives are possible. Use `--dry-run` first to review.
#
# 4. **Is this a security‑hardening tool?**
#    This is an *early‑warning* mechanism. For production you should also run code‑review pipelines and static analysis.
#
# Feel free to tweak it to match your own policy or integrate it into CI/CD. Happy scanning!
